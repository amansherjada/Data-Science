# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report
sns.set_theme(style='darkgrid')
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 200
# %matplotlib inline

# %%
col = ['SL','SW','PL','PW','class']
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
                header=None, names=col)
df
# Out:
#       SL   SW   PL   PW           class
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Understanding the distribution of data with 4D!

# %%
sns.scatterplot(x = df['PL'], y = df['PW'], s=100, hue=df['class'], edgecolor = 'black')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
sns.scatterplot(x = df['SL'], y = df['PW'], s=100, hue=df['class'], edgecolor = 'black')
plt.xlabel('Setosa Length')
plt.ylabel('Petal Width')
plt.show()
#We cannot understand the distribution of data because it is a 4 dimensional dataset

# %%
x = df.iloc[:,:-1] #Features
y = df['class'] #Target

# %% [markdown]
# Principal Component Analysis (PCA) is an unsupervised machine learning technique used for dimensionality reduction. It aims to identify patterns in data by transforming the original variables into a new set of uncorrelated variables called principal components.
#
# PCA does not require a target column because it focuses solely on the features (independent variables) present in the dataset. It works by identifying the directions (principal components) that capture the maximum variance in the data.

# %%
x
# Out:
#       SL   SW   PL   PW
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### PCA

# %%
sc = StandardScaler()

# %%
x = sc.fit_transform(x)

# %%
pd.DataFrame(x)
# Out:
#             0         1         2         3
# 0   -0.900681  1.032057 -1.341272 -1.312977
# 1   -1.143017 -0.124958 -1.341272 -1.312977
# 2   -1.385353  0.337848 -1.398138 -1.312977
# 3   -1.506521  0.106445 -1.284407 -1.312977
# 4   -1.021849  1.263460 -1.341272 -1.312977
# ..        ...       ...       ...       ...
# 145  1.038005 -0.124958  0.819624  1.447956
# 146  0.553333 -1.281972  0.705893  0.922064
# 147  0.795669 -0.124958  0.819624  1.053537
# 148  0.432165  0.800654  0.933356  1.447956
# 149  0.068662 -0.124958  0.762759  0.790591
#
# [150 rows x 4 columns]

# %%
pd.DataFrame(x).describe()
# Out:
#                   0             1             2             3
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean  -4.736952e-16 -6.631732e-16  3.315866e-16 -2.842171e-16
# std    1.003350e+00  1.003350e+00  1.003350e+00  1.003350e+00
# min   -1.870024e+00 -2.438987e+00 -1.568735e+00 -1.444450e+00
# 25%   -9.006812e-01 -5.877635e-01 -1.227541e+00 -1.181504e+00
# 50%   -5.250608e-02 -1.249576e-01  3.362659e-01  1.332259e-01
# 75%    6.745011e-01  5.692513e-01  7.627586e-01  7.905908e-01
# max    2.492019e+00  3.114684e+00  1.786341e+00  1.710902e+00

# %%
x
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
# from sklearn.decomposition import PCA
pca = PCA()

# %%
pcs = pca.fit_transform(x)

# %%
pd.DataFrame(pcs)
# Out:
#             0         1         2         3
# 0   -2.264542  0.505704 -0.121943 -0.023073
# 1   -2.086426 -0.655405 -0.227251 -0.103208
# 2   -2.367950 -0.318477  0.051480 -0.027825
# 3   -2.304197 -0.575368  0.098860  0.066311
# 4   -2.388777  0.674767  0.021428  0.037397
# ..        ...       ...       ...       ...
# 145  1.870522  0.382822  0.254532 -0.388890
# 146  1.558492 -0.905314 -0.025382 -0.221322
# 147  1.520845  0.266795  0.179277 -0.118903
# 148  1.376391  1.016362  0.931405 -0.024146
# 149  0.959299 -0.022284  0.528794  0.163676
#
# [150 rows x 4 columns]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.72770452, 0.23030523, 0.03683832, 0.00515193])

# %% [markdown]
# - explained_variance_ratio_ Gives insight into how much information each principal component captures from the original data.
# - The explained_variance_ratio_ tells you the proportion of variance (or information) captured by each principal component.
# -
# For example, if you have three principal components, and the explained_variance_ratio_ shows [0.7, 0.2, 0.1], it means the first component explains 70% of the variance, the second explains 20%, and the third explains 10%.

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.72770452, 0.95800975, 0.99484807, 1.        ])

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title('Scree Plot', size =20)
plt.xlabel('Priciple Components')
plt.ylabel('Explained Varience')
plt.axvline(x = 1.0, color='red', linestyle='--')
plt.show()

# %%
# First 2 princple componets is enough for us

# %%
pca = PCA(n_components=2)
pcs = pca.fit_transform(x)
pcs
# Out:
# array([[-2.26454173e+00,  5.05703903e-01],
#        [-2.08642550e+00, -6.55404729e-01],
#        [-2.36795045e+00, -3.18477311e-01],
#        [-2.30419716e+00, -5.75367713e-01],
#        [-2.38877749e+00,  6.74767397e-01],
#        [-2.07053681e+00,  1.51854856e+00],
#        [-2.44571134e+00,  7.45626750e-02],
#        [-2.23384186e+00,  2.47613932e-01],
#        [-2.34195768e+00, -1.09514636e+00],
#        [-2.18867576e+00, -4.48629048e-01],
#        [-2.16348656e+00,  1.07059558e+00],
#        [-2.32737775e+00,  1.58587455e-01],
#        [-2.22408272e+00, -7.09118158e-01],
#        [-2.63971626e+00, -9.38281982e-01],
#        [-2.19229151e+00,  1.88997851e+00],
#        [-2.25146521e+00,  2.72237108e+00],
#        [-2.20275048e+00,  1.51375028e+00],
#        [-2.19017916e+00,  5.14304308e-01],
#        [-1.89407429e+00,  1.43111071e+00],
#        [-2.33994907e+00,  1.15803343e+00],
#        [-1.91455639e+00,  4.30465163e-01],
#        [-2.20464540e+00,  9.52457317e-01],
# ...

# %%
pd.DataFrame(pcs)
# Out:
#             0         1
# 0   -2.264542  0.505704
# 1   -2.086426 -0.655405
# 2   -2.367950 -0.318477
# 3   -2.304197 -0.575368
# 4   -2.388777  0.674767
# ..        ...       ...
# 145  1.870522  0.382822
# 146  1.558492 -0.905314
# 147  1.520845  0.266795
# 148  1.376391  1.016362
# 149  0.959299 -0.022284
#
# [150 rows x 2 columns]

# %%
data = pd.DataFrame(pcs, columns=['PC1','PC2'])
data
# Out:
#           PC1       PC2
# 0   -2.264542  0.505704
# 1   -2.086426 -0.655405
# 2   -2.367950 -0.318477
# 3   -2.304197 -0.575368
# 4   -2.388777  0.674767
# ..        ...       ...
# 145  1.870522  0.382822
# 146  1.558492 -0.905314
# 147  1.520845  0.266795
# 148  1.376391  1.016362
# 149  0.959299 -0.022284
#
# [150 rows x 2 columns]

# %%
data['Class'] = y
# we stored the target coloum from original dataset into y (y = df['class'] #Target)

# %%
data
# Out:
#           PC1       PC2           Class
# 0   -2.264542  0.505704     Iris-setosa
# 1   -2.086426 -0.655405     Iris-setosa
# 2   -2.367950 -0.318477     Iris-setosa
# 3   -2.304197 -0.575368     Iris-setosa
# 4   -2.388777  0.674767     Iris-setosa
# ..        ...       ...             ...
# 145  1.870522  0.382822  Iris-virginica
# 146  1.558492 -0.905314  Iris-virginica
# 147  1.520845  0.266795  Iris-virginica
# 148  1.376391  1.016362  Iris-virginica
# 149  0.959299 -0.022284  Iris-virginica
#
# [150 rows x 3 columns]

# %%
data['PC1'].mean()
# Out:
# -9.473903143468003e-17

# %%
sns.scatterplot(x =data['PC1'], y = data['PC2'],s = 50, edgecolor = 'black', hue = data['Class'])
plt.scatter(pcs[:,0].mean(), pcs[:,1].mean(), s = 150, c= 'red' , edgecolor= 'black')

# %%
data
# Out:
#           PC1       PC2           Class
# 0   -2.264542  0.505704     Iris-setosa
# 1   -2.086426 -0.655405     Iris-setosa
# 2   -2.367950 -0.318477     Iris-setosa
# 3   -2.304197 -0.575368     Iris-setosa
# 4   -2.388777  0.674767     Iris-setosa
# ..        ...       ...             ...
# 145  1.870522  0.382822  Iris-virginica
# 146  1.558492 -0.905314  Iris-virginica
# 147  1.520845  0.266795  Iris-virginica
# 148  1.376391  1.016362  Iris-virginica
# 149  0.959299 -0.022284  Iris-virginica
#
# [150 rows x 3 columns]

# %%
# Building Logistic Regression model oo the PCA generated data

# %%
x = data.iloc[:,:-1]
y = data['Class']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
lg = LogisticRegression()
lg.fit(xtrain, ytrain)

ypred = lg.predict(xtest)
print(classification_report(ytest, ypred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# As we can see even after selecting the 50% data, still we are able to gte 97% accuracy of the model
